# %%
import pandas as pd
import statsmodels.api as sm
x=pd.read_csv("C:/Users/charumathi/downloads/Advertising.csv")
df=pd.DataFrame(x)
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 16           17   67.8   36.6      114.0   12.5
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   radio       200 non-null    float64
#  3   newspaper   200 non-null    float64
#  4   sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.shape
# Out:
# (200, 5)

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
import pandas as pd
pd.set_option("display.max_row",200)
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.hist(df["TV"],color="green")
# Out:
# (array([26., 15., 21., 18., 19., 17., 22., 26., 20., 16.]),
#  array([  0.7 ,  30.27,  59.84,  89.41, 118.98, 148.55, 178.12, 207.69,
#         237.26, 266.83, 296.4 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.bar(df["newspaper"],height=df["radio"].values)
# Out:
# <BarContainer object of 200 artists>

# %%
import seaborn as sns
sns.boxplot(x=df["newspaper"],y=df["TV"])
# Out:
# <AxesSubplot:xlabel='newspaper', ylabel='TV'>

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
X=df.iloc[:,1]
y=df.iloc[:,4]

# %%
import numpy as np
X=np.array(X).reshape(-1,1)
y=np.array(y).reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((160, 1), (40, 1), (160, 1), (40, 1))

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(X_test)
y_pred_train=regressor.predict(X_train)

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse_test=sqrt(mean_squared_error(y_test,y_pred))
print("Root Mean Squared Error for test data",rmse_test)
# Out:
# Root Mean Squared Error for test data 3.191579849311344

# %%
from sklearn.metrics import r2_score
r2s_test=r2_score(y_pred,y_test)
print("R2 score accuracy of test data",r2s_test)
# Out:
# R2 score accuracy of test data 0.3781249875842623
